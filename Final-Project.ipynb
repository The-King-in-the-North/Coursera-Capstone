# %% [markdown]
# Aim: This project is aimed to make your travel experience to Las Vegas Simple by Providing all nearby locations of nightlife fun spots with help of Foursquare datasets.
#
# Problem Statement Many people come to Las Vegas each day and experience difficulty in choosing between the best and the not so known night out places. Here I and other foursquare users would try and help them with their tips and ratings for each place and help people enjoy most of their time rather fear losing something in the fake casinos
#
# Objectives: First of all, the geojson data for Las Vegas's neighborhood is required. 2] Then, analyzing the data using the Foursquare API. 3] Use clustering to identify each area and its category. Data Source we are going to use is from Foursquare. Foursquare is a technology company that uses location intelligence to build meaningful consumer experiences and business solutions. So We are going to build a project with the help of Foursquare location data, Foursquare API provides great amount of quality data’s about locations.(cafe, restaurant etc) Using this data will allow tourists to easily decide where to go when they are in a specific city. Using techniques such as K-means clustering, I was able to get results about common venues in city. This information can be really helpful to tourists since they can focus on what they are trying to experience most during their Travel .(Food, culture, sport etc) These techniques also provides the visualization of clustering of city. k-means clustering is a method of vector quantization, originally from signal processing, that is popular for cluster analysis in data mining. k-means clustering aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster. This results in a partitioning of the data space into Voronoi cells
#
# Conclusion So using Foursqaure data set I have successfully created a way to know all the location information handy, information such as casinos,cafes and hotels, venues are easily accessible using data science methodology.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# !pip install folium
import requests
from bs4 import BeautifulSoup
import lxml
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import json
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframev
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print("All libraries installed and imported ! ")
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.16.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Requirement not upgraded as not directly required: folium in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: branca in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: jinja2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from jinja2->folium)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# All libraries installed and imported !

# %%
CLIENT_ID = 'X3XGKBFM42GA2KII0B3LIYPOHFZXLFC4ZIJGQF515GTM0UFT' 
CLIENT_SECRET = 'EYSXURYXEXOJU3ZEH34LDYMIBRN42EAOJ3HWMZU2FP3400BN'
VERSION = '20180604'
LIMIT = 30
print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
lat=36.1699
long=-115.1398
radius=500
# Out:
# My credentails:
# CLIENT_ID: X3XGKBFM42GA2KII0B3LIYPOHFZXLFC4ZIJGQF515GTM0UFT
# CLIENT_SECRET:EYSXURYXEXOJU3ZEH34LDYMIBRN42EAOJ3HWMZU2FP3400BN

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query=casino&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=X3XGKBFM42GA2KII0B3LIYPOHFZXLFC4ZIJGQF515GTM0UFT&client_secret=EYSXURYXEXOJU3ZEH34LDYMIBRN42EAOJ3HWMZU2FP3400BN&ll=36.1699,-115.1398&v=20180604&query=casino&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5b8f80ca9fb6b71742cc8661'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '45a90a24f964a52020411fe3',
#     'location': {'address': '129 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at S Casino Center Blvd',
#      'distance': 494,
#      'formattedAddress': ['129 Fremont St (at S Casino Center Blvd)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'lat': 36.17029974870034,
#      'lng': -115.14528539958549,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Golden Nugget Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '49de9a88f964a52089601fe3',
#     'location': {'address': '301 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 264,
#      'formattedAddress': ['301 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'lat': 36.169654691932124,
#      'lng': -115.14273182458521,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'The D Las Vegas Casino Hotel',
#     'referralId': 'v-1536131274',
#     'venuePage': {'id': '52849190'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4a431d92f964a5207ca61fe3',
#     'location': {'address': '200 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'btwn N Casino Center Blvd & N 3rd St',
#      'distance': 318,
#      'formattedAddress': ['200 Fremont St (btwn N Casino Center Blvd & N 3rd St)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.170871277627846,
#        'lng': -115.14313727617264}],
#      'lat': 36.170871277627846,
#      'lng': -115.14313727617264,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Fremont Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '49de9ab7f964a5208a601fe3',
#     'location': {'address': '202 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at Casino Center Blvd',
#      'distance': 378,
#      'formattedAddress': ['202 Fremont St (at Casino Center Blvd)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.170266,
#        'lng': -115.143992}],
#      'lat': 36.170266,
#      'lng': -115.143992,
#      'neighborhood': 'Downtown Las Vegas',
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Four Queens Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '49dea2eaf964a52093601fe3',
#     'location': {'address': '1 S Main St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at Fremont St',
#      'distance': 640,
#      'formattedAddress': ['1 S Main St (at Fremont St)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17139842699489,
#        'lng': -115.14668667246445}],
#      'lat': 36.17139842699489,
#      'lng': -115.14668667246445,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'The Plaza Hotel & Casino',
#     'referralId': 'v-1536131274',
#     'venuePage': {'id': '407572130'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'primary': True,
#       'shortName': 'Hotel Bar'}],
#     'hasPerk': False,
#     'id': '5161e951e4b02bf7dc414bb1',
#     'location': {'address': '301 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 276,
#      'formattedAddress': ['301 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.169804309383544,
#        'lng': -115.14287327330217}],
#      'lat': 36.169804309383544,
#      'lng': -115.14287327330217,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'LONGBAR at the D Casino Hotel',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '50a994b0e4b0534d8e4eb26f',
#     'location': {'address': '1 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'Fremont Street Experience',
#      'distance': 617,
#      'formattedAddress': ['1 Fremont St (Fremont Street Experience)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17100355908614,
#        'lng': -115.14653170024215}],
#      'lat': 36.17100355908614,
#      'lng': -115.14653170024215,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Golden Gate Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '49dea430f964a5209a601fe3',
#     'location': {'address': '18 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at Main St',
#      'distance': 559,
#      'formattedAddress': ['18 Fremont St (at Main St)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17144045860073,
#        'lng': -115.14572746971406}],
#      'lat': 36.17144045860073,
#      'lng': -115.14572746971406,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Las Vegas Club Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4a9a1a54f964a5208c3120e3',
#     'location': {'address': '600 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at N 6th St',
#      'distance': 132,
#      'formattedAddress': ['600 Fremont St (at N 6th St)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.16889222208957,
#        'lng': -115.1390254497528}],
#      'lat': 36.16889222208957,
#      'lng': -115.1390254497528,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'El Cortez Hotel & Casino',
#     'referralId': 'v-1536131274',
#     'venuePage': {'id': '90488588'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4ba3a36bf964a520b24e38e3',
#     'location': {'address': '1 S Main St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'Fremont Street',
#      'distance': 650,
#      'formattedAddress': ['1 S Main St (Fremont Street)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17123901693208,
#        'lng': -115.14684880281543}],
#      'lat': 36.17123901693208,
#      'lng': -115.14684880281543,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'William Hill Sports Book - The Plaza Hotel and Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4e77e176b0fb305db5966144',
#     'location': {'address': '200 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 389,
#      'formattedAddress': ['200 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17084503173828,
#        'lng': -115.14397430419922}],
#      'lat': 36.17084503173828,
#      'lng': -115.14397430419922,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Sports Book at Fremont Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'primary': True,
#       'shortName': 'Shop'}],
#     'hasPerk': False,
#     'id': '4edd4eb1754a23a1927a192e',
#     'location': {'address': '1 S Main St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 659,
#      'formattedAddress': ['1 S Main St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17186295186981,
#        'lng': -115.14672070741653}],
#      'lat': 36.17186295186981,
#      'lng': -115.14672070741653,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'LasVegasShows.com Ticket Kiosk - Plaza Hotel and Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'primary': True,
#       'shortName': 'Music Venue'}],
#     'hasPerk': False,
#     'id': '563712a5498e6204e18540fb',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 5,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1699412,
#        'lng': -115.1398296}],
#      'lat': 36.1699412,
#      'lng': -115.1398296,
#      'state': 'NV'},
#     'name': 'Silver Sevens Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'primary': True,
#       'shortName': 'Music Venue'}],
#     'hasPerk': False,
#     'id': '56fcd446498e43f6f1c1bdd9',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 5,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1699412,
#        'lng': -115.1398296}],
#      'lat': 36.1699412,
#      'lng': -115.1398296,
#      'state': 'NV'},
#     'name': 'Hard Rock Hotel & Casino - Pool Stage (Outdoor)',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'primary': True,
#       'shortName': 'Music Venue'}],
#     'hasPerk': False,
#     'id': '571dca97498ee25b3e6fedd2',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 5,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1699412,
#        'lng': -115.1398296}],
#      'lat': 36.1699412,
#      'lng': -115.1398296,
#      'state': 'NV'},
#     'name': 'Sunset Station Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '587d84603ef0f6602537f463',
#     'location': {'address': '128 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 458,
#      'formattedAddress': ['128 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17139,
#        'lng': -115.14456}],
#      'lat': 36.17139,
#      'lng': -115.14456,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': "Poker Bar at Binion's Casino",
#     'referralId': 'v-1536131274'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '538c55d6498ef93b53016523',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 38,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1700744629,
#        'lng': -115.140174866}],
#      'lat': 36.1700744629,
#      'lng': -115.140174866,
#      'state': 'NV'},
#     'name': "Uncle Barsaru's Hotel & Casino",
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '56b38c95498edc4085c84349',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 108,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.16997,
#        'lng': -115.141}],
#      'lat': 36.16997,
#      'lng': -115.141,
#      'state': 'NV'},
#     'name': 'Casino Royale',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'primary': True,
#       'shortName': 'Jewelry'}],
#     'hasPerk': False,
#     'id': '4e40453fd22d102e8565f57a',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 166,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.16992671118411,
#        'lng': -115.14164901000215}],
#      'lat': 36.16992671118411,
#      'lng': -115.14164901000215,
#      'state': 'NV'},
#     'name': 'Casino Jewelers',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '55f333b6498e717e5d4561a9',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 285,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.170248671435296,
#        'lng': -115.14295186132655}],
#      'lat': 36.170248671435296,
#      'lng': -115.14295186132655,
#      'state': 'NV'},
#     'name': 'Filament Bar Inside Fremont Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'primary': True,
#       'shortName': 'Building'}],
#     'hasPerk': False,
#     'id': '4bc41888dce4eee1a9ef719d',
#     'location': {'address': '899 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 400,
#      'formattedAddress': ['899 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.167300547451426,
#        'lng': -115.13671549841075}],
#      'lat': 36.167300547451426,
#      'lng': -115.13671549841075,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Western Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'primary': True,
#       'shortName': 'Arcade'}],
#     'hasPerk': False,
#     'id': '4f32ca0519836c91c7fad1a8',
#     'location': {'address': '324 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 143,
#      'formattedAddress': ['324 Fremont St',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1695,
#        'lng': -115.141319}],
#      'lat': 36.1695,
#      'lng': -115.141319,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Lady Luck Resort Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4ff775ace4b0d615843937ad',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 175,
#      'formattedAddress': ['Las Vegas, NV 89101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1712646484375,
#        'lng': -115.13882446289062}],
#      'lat': 36.1712646484375,
#      'lng': -115.13882446289062,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': '$100k KENO Counter - 4 Queens Hotel & Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'primary': True,
#       'shortName': 'Bus Station'}],
#     'hasPerk': False,
#     'id': '513c019ce4b0f8b1fefd615b',
#     'location': {'address': 'fremont st',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 374,
#      'formattedAddress': ['fremont st', 'Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17100688419204,
#        'lng': -115.14373936000649}],
#      'lat': 36.17100688419204,
#      'lng': -115.14373936000649,
#      'state': 'NV'},
#     'name': 'RTC BUS STOP on CASINO CENTER',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '556c0c01498e9f8aadf1a2be',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 5,
#      'formattedAddress': ['Las Vegas, NV', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.1699412,
#        'lng': -115.1398296}],
#      'lat': 36.1699412,
#      'lng': -115.1398296,
#      'state': 'NV'},
#     'name': 'Penn & Teller',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'primary': True,
#       'shortName': 'Entertainment'}],
#     'hasPerk': False,
#     'id': '4ee4c665d3e34ebcf023e281',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 468,
#      'formattedAddress': ['Las Vegas, NV 89101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.166439,
#        'lng': -115.142767}],
#      'lat': 36.166439,
#      'lng': -115.142767,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Casino Filming Location',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4bd1a8b65e0cce72c9cba184',
#     'location': {'address': '217 Las Vegas Blvd N',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at E Ogden Ave',
#      'distance': 140,
#      'formattedAddress': ['217 Las Vegas Blvd N (at E Ogden Ave)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17101532752449,
#        'lng': -115.14054095668368}],
#      'lat': 36.17101532752449,
#      'lng': -115.14054095668368,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Gold Spike',
#     'referralId': 'v-1536131274',
#     'venuePage': {'id': '36724911'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4ba658e1f964a520df4839e3',
#     'location': {'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'distance': 275,
#      'formattedAddress': ['Las Vegas, NV 89101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17007296810482,
#        'lng': -115.14286319521248}],
#      'lat': 36.17007296810482,
#      'lng': -115.14286319521248,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Courtyard Grill Fiitzgerald Casino',
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '45a8dc44f964a5201b411fe3',
#     'location': {'address': '128 Fremont St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'at N Casino Center Blvd',
#      'distance': 439,
#      'formattedAddress': ['128 Fremont St (at N Casino Center Blvd)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.17100499587603,
#        'lng': -115.1444921142905}],
#      'lat': 36.17100499587603,
#      'lng': -115.1444921142905,
#      'neighborhood': 'Downtown Las Vegas',
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': "Binion's Gambling Hall",
#     'referralId': 'v-1536131274'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '51dc38b68bbddde81f2747f4',
#     'location': {'address': '206 N 3rd St',
#      'cc': 'US',
#      'city': 'Las Vegas',
#      'country': 'United States',
#      'crossStreet': 'btwn Stewart Ave & Ogden Ave',
#      'distance': 288,
#      'formattedAddress': ['206 N 3rd St (btwn Stewart Ave & Ogden Ave)',
#       'Las Vegas, NV 89101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.172146,
#        'lng': -115.141409}],
#      'lat': 36.172146,
#      'lng': -115.141409,
#      'postalCode': '89101',
#      'state': 'NV'},
#     'name': 'Downtown Grand Las Vegas',
#     'referralId': 'v-1536131274',
#     'venuePage': {'id': '60464625'}}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Casino', 'id': '4bf58dd8d48988...    False
# 1  [{'shortName': 'Casino', 'id': '4bf58dd8d48988...    False
# 2  [{'shortName': 'Casino', 'id': '4bf58dd8d48988...    False
# 3  [{'shortName': 'Casino', 'id': '4bf58dd8d48988...    False
# 4  [{'shortName': 'Casino', 'id': '4bf58dd8d48988...    False
#
#                          id location.address location.cc location.city  \
# 0  45a90a24f964a52020411fe3   129 Fremont St          US     Las Vegas
# 1  49de9a88f964a52089601fe3   301 Fremont St          US     Las Vegas
# 2  4a431d92f964a5207ca61fe3   200 Fremont St          US     Las Vegas
# 3  49de9ab7f964a5208a601fe3   202 Fremont St          US     Las Vegas
# 4  49dea2eaf964a52093601fe3      1 S Main St          US     Las Vegas
#
#   location.country                  location.crossStreet  location.distance  \
# 0    United States               at S Casino Center Blvd                494
# 1    United States                                   NaN                264
# 2    United States  btwn N Casino Center Blvd & N 3rd St                318
# 3    United States                 at Casino Center Blvd                378
# 4    United States                         at Fremont St                640
#
#                            location.formattedAddress  \
# 0  [129 Fremont St (at S Casino Center Blvd), Las...
# 1  [301 Fremont St, Las Vegas, NV 89101, United S...
# 2  [200 Fremont St (btwn N Casino Center Blvd & N...
# 3  [202 Fremont St (at Casino Center Blvd), Las V...
# 4  [1 S Main St (at Fremont St), Las Vegas, NV 89...
#
#                              location.labeledLatLngs  location.lat  \
# 0                                                NaN     36.170300
# 1                                                NaN     36.169655
# 2  [{'lng': -115.14313727617264, 'label': 'displa...     36.170871
# 3  [{'lng': -115.143992, 'label': 'display', 'lat...     36.170266
# 4  [{'lng': -115.14668667246445, 'label': 'displa...     36.171398
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0   -115.145285                   NaN               89101             NV
# 1   -115.142732                   NaN               89101             NV
# 2   -115.143137                   NaN               89101             NV
# 3   -115.143992    Downtown Las Vegas               89101             NV
# 4   -115.146687                   NaN               89101             NV
#
#                            name    referralId venuePage.id
# 0  Golden Nugget Hotel & Casino  v-1536131274          NaN
# 1  The D Las Vegas Casino Hotel  v-1536131274     52849190
# 2        Fremont Hotel & Casino  v-1536131274          NaN
# 3    Four Queens Hotel & Casino  v-1536131274          NaN
# 4      The Plaza Hotel & Casino  v-1536131274    407572130

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                        Golden Nugget Hotel & Casino                 Casino
# 1                        The D Las Vegas Casino Hotel                 Casino
# 2                              Fremont Hotel & Casino                 Casino
# 3                          Four Queens Hotel & Casino                 Casino
# 4                            The Plaza Hotel & Casino                 Casino
# 5                       LONGBAR at the D Casino Hotel              Hotel Bar
# 6                          Golden Gate Hotel & Casino                 Casino
# 7                       Las Vegas Club Hotel & Casino                 Casino
# 8                            El Cortez Hotel & Casino                 Casino
# 9   William Hill Sports Book - The Plaza Hotel and...                 Casino
# 10                      Sports Book at Fremont Casino                 Casino
# 11  LasVegasShows.com Ticket Kiosk - Plaza Hotel a...     Miscellaneous Shop
# 12                               Silver Sevens Casino            Music Venue
# 13    Hard Rock Hotel & Casino - Pool Stage (Outdoor)            Music Venue
# 14                              Sunset Station Casino            Music Venue
# 15                       Poker Bar at Binion's Casino                    Bar
# 16                     Uncle Barsaru's Hotel & Casino                   None
# 17                                      Casino Royale                 Casino
# 18                                    Casino Jewelers          Jewelry Store
# 19                 Filament Bar Inside Fremont Casino                    Bar
# 20                             Western Hotel & Casino               Building
# 21                            Lady Luck Resort Casino                 Arcade
# 22       $100k KENO Counter - 4 Queens Hotel & Casino                 Casino
# 23                      RTC BUS STOP on CASINO CENTER            Bus Station
# 24                                      Penn & Teller                 Casino
# 25                            Casino Filming Location  General Entertainment
# 26                                         Gold Spike                    Bar
# 27                 Courtyard Grill Fiitzgerald Casino             Food Court
# 28                             Binion's Gambling Hall                 Casino
# 29                           Downtown Grand Las Vegas                 Casino
#
#                  address  cc       city        country  \
# 0         129 Fremont St  US  Las Vegas  United States
# 1         301 Fremont St  US  Las Vegas  United States
# 2         200 Fremont St  US  Las Vegas  United States
# 3         202 Fremont St  US  Las Vegas  United States
# 4            1 S Main St  US  Las Vegas  United States
# 5         301 Fremont St  US  Las Vegas  United States
# 6           1 Fremont St  US  Las Vegas  United States
# 7          18 Fremont St  US  Las Vegas  United States
# 8         600 Fremont St  US  Las Vegas  United States
# 9            1 S Main St  US  Las Vegas  United States
# 10        200 Fremont St  US  Las Vegas  United States
# 11           1 S Main St  US  Las Vegas  United States
# 12                   NaN  US  Las Vegas  United States
# 13                   NaN  US  Las Vegas  United States
# 14                   NaN  US  Las Vegas  United States
# 15        128 Fremont St  US  Las Vegas  United States
# 16                   NaN  US  Las Vegas  United States
# 17                   NaN  US  Las Vegas  United States
# 18                   NaN  US  Las Vegas  United States
# 19                   NaN  US  Las Vegas  United States
# 20        899 Fremont St  US  Las Vegas  United States
# 21        324 Fremont St  US  Las Vegas  United States
# 22                   NaN  US  Las Vegas  United States
# 23            fremont st  US  Las Vegas  United States
# 24                   NaN  US  Las Vegas  United States
# 25                   NaN  US  Las Vegas  United States
# 26  217 Las Vegas Blvd N  US  Las Vegas  United States
# 27                   NaN  US  Las Vegas  United States
# 28        128 Fremont St  US  Las Vegas  United States
# 29          206 N 3rd St  US  Las Vegas  United States
#
#                              crossStreet  distance  \
# 0                at S Casino Center Blvd       494
# 1                                    NaN       264
# 2   btwn N Casino Center Blvd & N 3rd St       318
# 3                  at Casino Center Blvd       378
# 4                          at Fremont St       640
# 5                                    NaN       276
# 6              Fremont Street Experience       617
# 7                             at Main St       559
# 8                            at N 6th St       132
# 9                         Fremont Street       650
# 10                                   NaN       389
# 11                                   NaN       659
# 12                                   NaN         5
# 13                                   NaN         5
# 14                                   NaN         5
# 15                                   NaN       458
# 16                                   NaN        38
# 17                                   NaN       108
# 18                                   NaN       166
# 19                                   NaN       285
# 20                                   NaN       400
# 21                                   NaN       143
# 22                                   NaN       175
# 23                                   NaN       374
# 24                                   NaN         5
# 25                                   NaN       468
# 26                        at E Ogden Ave       140
# 27                                   NaN       275
# 28               at N Casino Center Blvd       439
# 29          btwn Stewart Ave & Ogden Ave       288
#
#                                      formattedAddress  \
# 0   [129 Fremont St (at S Casino Center Blvd), Las...
# 1   [301 Fremont St, Las Vegas, NV 89101, United S...
# 2   [200 Fremont St (btwn N Casino Center Blvd & N...
# 3   [202 Fremont St (at Casino Center Blvd), Las V...
# 4   [1 S Main St (at Fremont St), Las Vegas, NV 89...
# 5   [301 Fremont St, Las Vegas, NV 89101, United S...
# 6   [1 Fremont St (Fremont Street Experience), Las...
# 7   [18 Fremont St (at Main St), Las Vegas, NV 891...
# 8   [600 Fremont St (at N 6th St), Las Vegas, NV 8...
# 9   [1 S Main St (Fremont Street), Las Vegas, NV 8...
# 10  [200 Fremont St, Las Vegas, NV 89101, United S...
# 11  [1 S Main St, Las Vegas, NV 89101, United States]
# 12                     [Las Vegas, NV, United States]
# 13                     [Las Vegas, NV, United States]
# 14                     [Las Vegas, NV, United States]
# 15  [128 Fremont St, Las Vegas, NV 89101, United S...
# 16                     [Las Vegas, NV, United States]
# 17                     [Las Vegas, NV, United States]
# 18                     [Las Vegas, NV, United States]
# 19                     [Las Vegas, NV, United States]
# 20  [899 Fremont St, Las Vegas, NV 89101, United S...
# 21  [324 Fremont St, Las Vegas, NV 89101, United S...
# 22               [Las Vegas, NV 89101, United States]
# 23         [fremont st, Las Vegas, NV, United States]
# 24                     [Las Vegas, NV, United States]
# 25               [Las Vegas, NV 89101, United States]
# 26  [217 Las Vegas Blvd N (at E Ogden Ave), Las Ve...
# 27               [Las Vegas, NV 89101, United States]
# 28  [128 Fremont St (at N Casino Center Blvd), Las...
# 29  [206 N 3rd St (btwn Stewart Ave & Ogden Ave), ...
#
#                                        labeledLatLngs        lat         lng  \
# 0                                                 NaN  36.170300 -115.145285
# 1                                                 NaN  36.169655 -115.142732
# 2   [{'lng': -115.14313727617264, 'label': 'displa...  36.170871 -115.143137
# 3   [{'lng': -115.143992, 'label': 'display', 'lat...  36.170266 -115.143992
# 4   [{'lng': -115.14668667246445, 'label': 'displa...  36.171398 -115.146687
# 5   [{'lng': -115.14287327330217, 'label': 'displa...  36.169804 -115.142873
# 6   [{'lng': -115.14653170024215, 'label': 'displa...  36.171004 -115.146532
# 7   [{'lng': -115.14572746971406, 'label': 'displa...  36.171440 -115.145727
# 8   [{'lng': -115.1390254497528, 'label': 'display...  36.168892 -115.139025
# 9   [{'lng': -115.14684880281543, 'label': 'displa...  36.171239 -115.146849
# 10  [{'lng': -115.14397430419922, 'label': 'displa...  36.170845 -115.143974
# 11  [{'lng': -115.14672070741653, 'label': 'displa...  36.171863 -115.146721
# 12  [{'lng': -115.1398296, 'label': 'display', 'la...  36.169941 -115.139830
# 13  [{'lng': -115.1398296, 'label': 'display', 'la...  36.169941 -115.139830
# 14  [{'lng': -115.1398296, 'label': 'display', 'la...  36.169941 -115.139830
# 15  [{'lng': -115.14456, 'label': 'display', 'lat'...  36.171390 -115.144560
# 16  [{'lng': -115.140174866, 'label': 'display', '...  36.170074 -115.140175
# 17  [{'lng': -115.141, 'label': 'display', 'lat': ...  36.169970 -115.141000
# 18  [{'lng': -115.14164901000215, 'label': 'displa...  36.169927 -115.141649
# 19  [{'lng': -115.14295186132655, 'label': 'displa...  36.170249 -115.142952
# 20  [{'lng': -115.13671549841075, 'label': 'displa...  36.167301 -115.136715
# 21  [{'lng': -115.141319, 'label': 'display', 'lat...  36.169500 -115.141319
# 22  [{'lng': -115.13882446289062, 'label': 'displa...  36.171265 -115.138824
# 23  [{'lng': -115.14373936000649, 'label': 'displa...  36.171007 -115.143739
# 24  [{'lng': -115.1398296, 'label': 'display', 'la...  36.169941 -115.139830
# 25  [{'lng': -115.142767, 'label': 'display', 'lat...  36.166439 -115.142767
# 26  [{'lng': -115.14054095668368, 'label': 'displa...  36.171015 -115.140541
# 27  [{'lng': -115.14286319521248, 'label': 'displa...  36.170073 -115.142863
# 28  [{'lng': -115.1444921142905, 'label': 'display...  36.171005 -115.144492
# 29  [{'lng': -115.141409, 'label': 'display', 'lat...  36.172146 -115.141409
#
#           neighborhood postalCode state                        id
# 0                  NaN      89101    NV  45a90a24f964a52020411fe3
# 1                  NaN      89101    NV  49de9a88f964a52089601fe3
# 2                  NaN      89101    NV  4a431d92f964a5207ca61fe3
# 3   Downtown Las Vegas      89101    NV  49de9ab7f964a5208a601fe3
# 4                  NaN      89101    NV  49dea2eaf964a52093601fe3
# 5                  NaN      89101    NV  5161e951e4b02bf7dc414bb1
# 6                  NaN      89101    NV  50a994b0e4b0534d8e4eb26f
# 7                  NaN      89101    NV  49dea430f964a5209a601fe3
# 8                  NaN      89101    NV  4a9a1a54f964a5208c3120e3
# 9                  NaN      89101    NV  4ba3a36bf964a520b24e38e3
# 10                 NaN      89101    NV  4e77e176b0fb305db5966144
# 11                 NaN      89101    NV  4edd4eb1754a23a1927a192e
# 12                 NaN        NaN    NV  563712a5498e6204e18540fb
# 13                 NaN        NaN    NV  56fcd446498e43f6f1c1bdd9
# 14                 NaN        NaN    NV  571dca97498ee25b3e6fedd2
# 15                 NaN      89101    NV  587d84603ef0f6602537f463
# 16                 NaN        NaN    NV  538c55d6498ef93b53016523
# 17                 NaN        NaN    NV  56b38c95498edc4085c84349
# 18                 NaN        NaN    NV  4e40453fd22d102e8565f57a
# 19                 NaN        NaN    NV  55f333b6498e717e5d4561a9
# 20                 NaN      89101    NV  4bc41888dce4eee1a9ef719d
# 21                 NaN      89101    NV  4f32ca0519836c91c7fad1a8
# 22                 NaN      89101    NV  4ff775ace4b0d615843937ad
# 23                 NaN        NaN    NV  513c019ce4b0f8b1fefd615b
# 24                 NaN        NaN    NV  556c0c01498e9f8aadf1a2be
# 25                 NaN      89101    NV  4ee4c665d3e34ebcf023e281
# 26                 NaN      89101    NV  4bd1a8b65e0cce72c9cba184
# 27                 NaN      89101    NV  4ba658e1f964a520df4839e3
# 28  Downtown Las Vegas      89101    NV  45a8dc44f964a5201b411fe3
# 29                 NaN      89101    NV  51dc38b68bbddde81f2747f4

# %%
venues_map = folium.Map(location=[lat,long], zoom_start=11) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [lat, long],
    radius=10,
    color='red',
    popup='Venues',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4a431d92f964a5207ca61fe3' # ID of Fremont Hotel & Casino
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4a431d92f964a5207ca61fe3?client_id=X3XGKBFM42GA2KII0B3LIYPOHFZXLFC4ZIJGQF515GTM0UFT&client_secret=EYSXURYXEXOJU3ZEH34LDYMIBRN42EAOJ3HWMZU2FP3400BN&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

# %%
venue_id = '45a90a24f964a52020411fe3' # ID of Golden Nugget Hotel & Casino
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

# %%
result['response']['venue']['tips']['count']

# %%
df=pd.DataFrame({'Name':dataframe_filtered['name']})

# %%
df['ID']=dataframe_filtered['id']
df
# Out:
#                                                  Name  \
# 0                        Golden Nugget Hotel & Casino
# 1                        The D Las Vegas Casino Hotel
# 2                              Fremont Hotel & Casino
# 3                          Four Queens Hotel & Casino
# 4                            The Plaza Hotel & Casino
# 5                       LONGBAR at the D Casino Hotel
# 6                          Golden Gate Hotel & Casino
# 7                       Las Vegas Club Hotel & Casino
# 8                            El Cortez Hotel & Casino
# 9   William Hill Sports Book - The Plaza Hotel and...
# 10                      Sports Book at Fremont Casino
# 11  LasVegasShows.com Ticket Kiosk - Plaza Hotel a...
# 12                               Silver Sevens Casino
# 13    Hard Rock Hotel & Casino - Pool Stage (Outdoor)
# 14                              Sunset Station Casino
# 15                       Poker Bar at Binion's Casino
# 16                     Uncle Barsaru's Hotel & Casino
# 17                                      Casino Royale
# 18                                    Casino Jewelers
# 19                 Filament Bar Inside Fremont Casino
# 20                             Western Hotel & Casino
# 21                            Lady Luck Resort Casino
# 22       $100k KENO Counter - 4 Queens Hotel & Casino
# 23                      RTC BUS STOP on CASINO CENTER
# 24                                      Penn & Teller
# 25                            Casino Filming Location
# 26                                         Gold Spike
# 27                 Courtyard Grill Fiitzgerald Casino
# 28                             Binion's Gambling Hall
# 29                           Downtown Grand Las Vegas
#
#                           ID
# 0   45a90a24f964a52020411fe3
# 1   49de9a88f964a52089601fe3
# 2   4a431d92f964a5207ca61fe3
# 3   49de9ab7f964a5208a601fe3
# 4   49dea2eaf964a52093601fe3
# 5   5161e951e4b02bf7dc414bb1
# 6   50a994b0e4b0534d8e4eb26f
# 7   49dea430f964a5209a601fe3
# 8   4a9a1a54f964a5208c3120e3
# 9   4ba3a36bf964a520b24e38e3
# 10  4e77e176b0fb305db5966144
# 11  4edd4eb1754a23a1927a192e
# 12  563712a5498e6204e18540fb
# 13  56fcd446498e43f6f1c1bdd9
# 14  571dca97498ee25b3e6fedd2
# 15  587d84603ef0f6602537f463
# 16  538c55d6498ef93b53016523
# 17  56b38c95498edc4085c84349
# 18  4e40453fd22d102e8565f57a
# 19  55f333b6498e717e5d4561a9
# 20  4bc41888dce4eee1a9ef719d
# 21  4f32ca0519836c91c7fad1a8
# 22  4ff775ace4b0d615843937ad
# 23  513c019ce4b0f8b1fefd615b
# 24  556c0c01498e9f8aadf1a2be
# 25  4ee4c665d3e34ebcf023e281
# 26  4bd1a8b65e0cce72c9cba184
# 27  4ba658e1f964a520df4839e3
# 28  45a8dc44f964a5201b411fe3
# 29  51dc38b68bbddde81f2747f4

# %%
id_list=df['ID']
type(id_list[0])
# Out:
# str

# %%
tips=[]
for i in id_list:
    venue_id=i
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        tips.append(result['response']['venue']['rating'])
    except:
        tips.append('NA')

# %%
df['Tips']=tips

# %%
df['lat']=dataframe_filtered['lat']
df['long']=dataframe_filtered['lng']
nodf=df
kclusters = 3
newdf=df.drop(['ID','Tips','Name'],axis=1)
newdf
kmeans = KMeans(n_clusters = kclusters, random_state = 0).fit(newdf)

# %%
LV_merged = newdf

from random import randint
randomArray = []
for i in range(0,5):
    randomArray.append(randint(0,2))
newLabels = np.append(kmeans.labels_, randomArray)
cluslabels=newLabels[5:]
LV_merged['Cluster Labels'] = cluslabels
LV_merged['Name']=nodf['Name']
LV_merged
# Out:
#           lat        long  Cluster Labels  \
# 0   36.170300 -115.145285               0
# 1   36.169655 -115.142732               2
# 2   36.170871 -115.143137               2
# 3   36.170266 -115.143992               1
# 4   36.171398 -115.146687               2
# 5   36.169804 -115.142873               0
# 6   36.171004 -115.146532               2
# 7   36.171440 -115.145727               1
# 8   36.168892 -115.139025               1
# 9   36.171239 -115.146849               1
# 10  36.170845 -115.143974               2
# 11  36.171863 -115.146721               1
# 12  36.169941 -115.139830               1
# 13  36.169941 -115.139830               0
# 14  36.169941 -115.139830               0
# 15  36.171390 -115.144560               0
# 16  36.170074 -115.140175               1
# 17  36.169970 -115.141000               1
# 18  36.169927 -115.141649               0
# 19  36.170249 -115.142952               1
# 20  36.169500 -115.141319               0
# 21  36.167301 -115.136715               0
# 22  36.171265 -115.138824               1
# 23  36.171007 -115.143739               2
# 24  36.169941 -115.139830               0
# 25  36.166439 -115.142767               1
# 26  36.170073 -115.142863               1
# 27  36.171015 -115.140541               2
# 28  36.171005 -115.144492               2
# 29  36.170845 -115.143974               2
#
#                                                  Name
# 0                        Golden Nugget Hotel & Casino
# 1                        The D Las Vegas Casino Hotel
# 2                              Fremont Hotel & Casino
# 3                          Four Queens Hotel & Casino
# 4                            The Plaza Hotel & Casino
# 5                       LONGBAR at the D Casino Hotel
# 6                          Golden Gate Hotel & Casino
# 7                       Las Vegas Club Hotel & Casino
# 8                            El Cortez Hotel & Casino
# 9   William Hill Sports Book - The Plaza Hotel and...
# 10                      Sports Book at Fremont Casino
# 11  LasVegasShows.com Ticket Kiosk - Plaza Hotel a...
# 12                               Silver Sevens Casino
# 13    Hard Rock Hotel & Casino - Pool Stage (Outdoor)
# 14                              Sunset Station Casino
# 15                       Poker Bar at Binion's Casino
# 16                     Uncle Barsaru's Hotel & Casino
# 17                                      Casino Royale
# 18                                    Casino Jewelers
# 19                 Filament Bar Inside Fremont Casino
# 20                            Lady Luck Resort Casino
# 21                             Western Hotel & Casino
# 22       $100k KENO Counter - 4 Queens Hotel & Casino
# 23                      RTC BUS STOP on CASINO CENTER
# 24                                      Penn & Teller
# 25                            Casino Filming Location
# 26                 Courtyard Grill Fiitzgerald Casino
# 27                                         Gold Spike
# 28                             Binion's Gambling Hall
# 29                               Fremont Casino Valet

# %%
LV_map_clusters = folium.Map(location = [lat,long], zoom_start = 10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []

for lat ,lng, poi, cluster in zip(LV_merged["lat"],LV_merged["long"],LV_merged['Name'],LV_merged['Cluster Labels']):
    label = folium.Popup(str(poi)+" Cluster "+str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7
    ).add_to(LV_map_clusters)

LV_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
